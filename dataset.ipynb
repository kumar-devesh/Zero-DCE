# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks/Zero-DCE/datasets
# Out:
# /content/drive/MyDrive/Colab Notebooks/Zero-DCE/datasets

# %%
# !gdown https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6
# !unzip -q lol_dataset.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6
# To: /content/drive/MyDrive/Colab Notebooks/Zero-DCE/datasets/lol_dataset.zip
# 100% 347M/347M [00:08<00:00, 38.8MB/s]

# %%
cd ./lol_dataset/our485/low
# Out:
# /content/drive/My Drive/Colab Notebooks/Zero-DCE/datasets/lol_dataset/our485/low

# %%
rm .DS_Store
